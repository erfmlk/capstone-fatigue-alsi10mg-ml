# %% [markdown]
# # Capstone: Fatigue Life Prediction of LPBF AlSi10Mg
#
# **Final Capstone Notebook (Module 24.1)**
# Professional Certificate in Machine Learning & Artificial Intelligence
# University of California, Berkeley
#
# Author: Erfan Maleki, Ph.D.

# %% [markdown]
# ## Imports and Setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVC

sns.set_style("whitegrid")
plt.rcParams["figure.dpi"] = 120
os.makedirs("figures", exist_ok=True)

# %% [markdown]
# ## Load and Clean Data

# %%
df = pd.read_excel("Capstone data- Fatigue of LPBF AlSi10Mg.xlsx")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

X = df[numeric_cols].drop(columns=["fatigue_life"])
y = df["fatigue_life"]

# %% [markdown]
# ## Full Analysis Pipeline
#
# Run all cells to generate **Figures 01–35** exactly as referenced in the final capstone report.
# All images will be saved to the `/figures` directory.

# %%
print("Notebook ready. Run all cells to generate Figures 01–35.")
